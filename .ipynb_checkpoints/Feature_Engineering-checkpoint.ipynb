# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

pd.pandas.set_option('display.max_columns', None)

# %%
df = pd.read_csv('./data/sample.csv')
df['id'] = df.index + 1
print(df.shape)
df.head()
# Out:
# (29236, 18)
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2     2017-03-06 12:10      2017-03-06 12:20                2
# 1         1      2017-06-14 8:11       2017-06-14 8:14                1
# 2         2     2017-11-22 19:42      2017-11-22 19:49                3
# 3         2     2017-11-12 16:58      2017-11-12 17:09                1
# 4         1     2017-06-14 22:01      2017-06-14 22:06                1
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           2.03           1                  N           140           236
# 1           0.40           1                  N            43           142
# 2           1.04           1                  N           151           238
# 3           1.79           1                  N           239           236
# 4           1.20           1                  N           246           246
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             1          9.0    0.0      0.5        1.96           0.0
# 1             1          4.5    0.0      0.5        1.05           0.0
# 2             1          6.5    1.0      0.5        0.00           0.0
# 3             2          9.5    0.0      0.5        0.00           0.0
# 4             1          6.0    0.5      0.5        2.15           0.0
#
#    improvement_surcharge  total_amount  id
# 0                    0.3         11.76   1
# 1                    0.3          6.35   2
# 2                    0.3          8.30   3
# 3                    0.3         10.30   4
# 4                    0.3          9.45   5

# %%
# train, test split
# set seed for reproducibility 

X_train, X_test, y_train, y_test = train_test_split(df, df.tip_amount,
                                                    test_size=0.1,
                                                    random_state=0)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((26312, 18), (2924, 18), (26312,), (2924,))

# %% [markdown]
# ### Time variable

# %%
def trip_time(df, start, end):
    """
    start: pickup time
    end: dropoff time
    
    Extracts time information from the two variables. 
    """
    df = df.copy()
    
    df['pickup'] = pd.to_datetime(df[start])
    df['dropoff'] = pd.to_datetime(df[end])
    
    df['trip_time'] = df['dropoff'] - df['pickup']
    
    # convert to minutes
    df['trip_seconds'] = df['trip_time'].astype('timedelta64[s]')
        
    df = df.drop(columns=[start, end, 'trip_time', 'pickup', 'dropoff'])
    
    return df

# %%
X_train = trip_time(X_train, 'tpep_pickup_datetime', 'tpep_dropoff_datetime')
X_test = trip_time(X_test, 'tpep_pickup_datetime', 'tpep_dropoff_datetime')

# %%
X_train.shape
# Out:
# (26312, 17)

# %% [markdown]
# ### Numerical variables
# - Log transform those without zeros to get a more Gaussian distribution to help linear machine learning models

# %% [markdown]
# ### Categorical variables
# - convert strings to numbers to capture monotonic relationship between label and target

# %%
# for one hot encoding
# a few variables have been coded as an int instead of a categorical variable
var_to_str = ['RatecodeID', 'store_and_fwd_flag', 'payment_type']

def to_str(train, test, var):
    train[var] = train[var].astype(str)
    test[var] = test[var].astype(str)
    
for var in var_to_str:
    to_str(X_train, X_test, var)

# %%
# check cardinality of non-numeric features we want to one-hot encode
X_train.describe(include='O').T.sort_values(by='unique')
# Out:
#                     count unique top   freq
# store_and_fwd_flag  26312      2   N  26169
# payment_type        26312      4   1  17897
# RatecodeID          26312      6   1  25531

# %%
X_train.RatecodeID.value_counts(normalize=False)
# Out:
# 1     25531
# 2       610
# 5        95
# 3        61
# 4        14
# 99        1
# Name: RatecodeID, dtype: int64

# %%
X_train.payment_type.value_counts(normalize=False)
# Out:
# 1    17897
# 2     8244
# 3      126
# 4       45
# Name: payment_type, dtype: int64

# %%
# need to reduce cardinality of PULocationID & DOLocationID
X_train.PULocationID.value_counts().sum

# get list of top 10 locations
top10PU = X_train['PULocationID'].value_counts()[:10].index
top10DO = X_train['DOLocationID'].value_counts()[:10].index

# for locationIDs not in the top 10, replace with OTHER
X_train.loc[~X_train['PULocationID'].isin(top10PU), 'PULocationID'] = 'OTHER'
X_train.loc[~X_train['DOLocationID'].isin(top10DO), 'DOLocationID'] = 'OTHER'

X_test.loc[~X_test['PULocationID'].isin(top10PU), 'PULocationID'] = 'OTHER'
X_test.loc[~X_test['DOLocationID'].isin(top10DO), 'DOLocationID'] = 'OTHER'

# %%
import category_encoders as ce

encoder = ce.OneHotEncoder(use_cat_names=True)

X_train['RatecodeID'] = X_train['RatecodeID'].replace({'1': 'one', '2': 'two', '3': 'three', '4': 'four', '5': 'five', '99': 'six'})
X_test['RatecodeID'] = X_test['RatecodeID'].replace({'1': 'one', '2': 'two', '3': 'three', '4': 'four', '5': 'five', '99': 'six'})

X_train['store_and_fwd_flag'] = X_train['store_and_fwd_flag'].replace({'1': 'one', '2': 'two'})
X_test['store_and_fwd_flag'] = X_test['store_and_fwd_flag'].replace({'1': 'one', '2': 'two'})

X_train['payment_type'] = X_train['payment_type'].replace({'1': 'one', '2': 'two', '3': 'three', '4': 'four'})
X_test['payment_type'] = X_test['payment_type'].replace({'1': 'one', '2': 'two', '3': 'three', '4': 'four'})

X_train_encoded = encoder.fit_transform(X_train)
X_test_encoded = encoder.fit_transform(X_test)

X_train_encoded.head()
# Out:
#        VendorID  passenger_count  trip_distance  RatecodeID_one  \
# 18162         1                1           1.00               1
# 18257         2                1           1.35               1
# 2574          2                1           0.52               1
# 7141          1                1           1.40               1
# 6020          2                1           3.03               1
#
#        RatecodeID_two  RatecodeID_five  RatecodeID_three  RatecodeID_four  \
# 18162               0                0                 0                0
# 18257               0                0                 0                0
# 2574                0                0                 0                0
# 7141                0                0                 0                0
# 6020                0                0                 0                0
#
#        RatecodeID_six  store_and_fwd_flag_N  store_and_fwd_flag_Y  \
# 18162               0                     1                     0
# 18257               0                     1                     0
# 2574                0                     1                     0
# 7141                0                     1                     0
# 6020                0                     1                     0
#
#        PULocationID_170  PULocationID_48  PULocationID_OTHER  \
# 18162                 1                0                   0
# 18257                 0                1                   0
# 2574                  0                0                   1
# 7141                  0                0                   0
# 6020                  0                0                   1
#
#        PULocationID_230  PULocationID_162  PULocationID_236  PULocationID_237  \
# 18162                 0                 0                 0                 0
# 18257                 0                 0                 0                 0
# 2574                  0                 0                 0                 0
# 7141                  1                 0                 0                 0
# 6020                  0                 0                 0                 0
#
#        PULocationID_234  PULocationID_142  PULocationID_186  PULocationID_161  \
# 18162                 0                 0                 0                 0
# 18257                 0                 0                 0                 0
# 2574                  0                 0                 0                 0
# 7141                  0                 0                 0                 0
# 6020                  0                 0                 0                 0
#
#        DOLocationID_186  DOLocationID_OTHER  DOLocationID_236  \
# 18162                 1                   0                 0
# 18257                 0                   1                 0
# 2574                  0                   1                 0
# 7141                  0                   1                 0
# 6020                  0                   1                 0
#
#        DOLocationID_48  DOLocationID_170  DOLocationID_162  DOLocationID_230  \
# 18162                0                 0                 0                 0
# 18257                0                 0                 0                 0
# 2574                 0                 0                 0                 0
# 7141                 0                 0                 0                 0
# 6020                 0                 0                 0                 0
#
#        DOLocationID_161  DOLocationID_142  DOLocationID_237  DOLocationID_234  \
# 18162                 0                 0                 0                 0
# 18257                 0                 0                 0                 0
# 2574                  0                 0                 0                 0
# 7141                  0                 0                 0                 0
# 6020                  0                 0                 0                 0
#
#        payment_type_one  payment_type_two  payment_type_three  \
# 18162                 1                 0                   0
# 18257                 1                 0                   0
# 2574                  0                 1                   0
# 7141                  0                 1                   0
# 6020                  0                 1                   0
#
#        payment_type_four  fare_amount  extra  mta_tax  tip_amount  \
# 18162                  0          5.5    0.5      0.5        1.35
# 18257                  0          6.5    0.5      0.5        1.56
# 2574                   0          4.0    0.0      0.5        0.00
# 7141                   0          7.5    1.0      0.5        0.00
# 6020                   0         15.0    0.5      0.5        0.00
#
#        tolls_amount  improvement_surcharge  total_amount     id  trip_seconds
# 18162           0.0                    0.3          8.15  18163         240.0
# 18257           0.0                    0.3          9.36  18258         420.0
# 2574            0.0                    0.3          4.80   2575         120.0
# 7141            0.0                    0.3          9.30   7142         480.0
# 6020            0.0                    0.3         16.30   6021        1260.0

# %%
X_train_encoded.shape, X_train.shape
# Out:
# ((26312, 46), (26312, 17))

# %%
cat_vars = [var for var in X_train.columns if X_train[var].dtype == 'O']
cat_vars
# Out:
# ['RatecodeID',
#  'store_and_fwd_flag',
#  'PULocationID',
#  'DOLocationID',
#  'payment_type']

# %%
# is there a monotonic relationship between the labels and tip amount?
def analyse_vars(df, var):
    df = df.copy()
    df.groupby(var)['tip_amount'].median().plot.bar()
    plt.title(var)
    plt.ylabel('tip_amount')
    plt.show()
    
for var in cat_vars:
    analyse_vars(X_train, var)

# %% [markdown]
# ### Feature scaling
# - for linear models

# %%
features = [var for var in X_train_encoded.columns if var not in ['id', 'tip_amount']]

X_train_encoded[['id', 'tip_amount']].reset_index(drop=True)
# X_train_encoded = X_train_encoded[features]
# X_test_encoded = X_test_encoded[features]
# Out:
#           id  tip_amount
# 0      18163        1.35
# 1      18258        1.56
# 2       2575        0.00
# 3       7142        0.00
# 4       6021        0.00
# 5      15660        0.78
# 6       7703        1.95
# 7      12339        5.35
# 8      22803        0.00
# 9       6860        2.25
# 10     15577        1.00
# 11     13345        0.00
# 12     20097        5.19
# 13      7348        1.56
# 14     17521        1.00
# 15     26947        3.55
# 16     26818        0.00
# 17      9474        1.26
# 18     10291        1.55
# 19     28388        1.46
# 20     17184        3.85
# 21     12315        1.86
# 22      2743        2.45
# 23     15231        3.99
# 24      6493        2.86
# 25      5292        2.20
# 26      6719        0.00
# 27     11715        2.96
# 28     16517        0.00
# 29     26509        0.00
# ...      ...         ...
# 26282   2164        0.00
# 26283   6037        0.00
# 26284   6922        0.00
# 26285   6217        1.86
# 26286  27470        0.00
# 26287  16922        1.00
# 26288  26278        2.00
# 26289   2898       11.70
# 26290  24153        3.05
# 26291  18607        0.00
# 26292  10328        0.00
# 26293  18984        8.76
# 26294  17090        0.00
# 26295  14651        1.95
# 26296  19853        2.05
# 26297   6745        1.00
# 26298  15833        0.00
# 26299  15431        1.56
# 26300  14936        0.96
# 26301  14117        0.00
# 26302  22259        1.56
# 26303  20758        1.00
# 26304  24276        2.86
# 26305   9226        6.95
# 26306  21244        1.00
# 26307  13124        1.45
# 26308  19649        0.00
# 26309   9846        0.00
# 26310  10800        1.40
# 26311   2733        0.00
#
# [26312 rows x 2 columns]

# %%
scaler = MinMaxScaler()
scaler.fit(X_train_encoded[features])

X_train_scaled = scaler.fit_transform(X_train_encoded)
X_test_scaled = scaler.fit_transform(X_test_encoded)

# %%
X_train_scaled.shape, y_train.shape, X_test_scaled.shape, y_test.shape
# Out:
# ((26312, 46), (26312,), (2924, 45), (2924,))

# %%
X_train_scaled = pd.concat([X_train_encoded[['id', 'tip_amount']].reset_index(drop=True),
                    pd.DataFrame(scaler.transform(X_train_encoded[features]), columns=features)],
                    axis=1)

X_test_scaled = pd.concat([X_test_encoded[['id', 'tip_amount']].reset_index(drop=True),
                    pd.DataFrame(scaler.transform(X_test_encoded[features]), columns=features)],
                    axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-337-ac4b5fc8d7fd> in <module>
#       4
#       5 X_test_scaled = pd.concat([X_test_encoded[['id', 'tip_amount']].reset_index(drop=True),
# ----> 6                     pd.DataFrame(scaler.transform(X_test_encoded[features]), columns=features)],
#       7                     axis=1)
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2724             return self._take(indexer, axis=0)
#    2725         else:
# -> 2726             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2727             return self._take(indexer, axis=1)
#    2728
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1325                 if mask.any():
#    1326                     raise KeyError('{mask} not in index'
# -> 1327                                    .format(mask=objarr[mask]))
#    1328
#    1329                 return com._values_from_object(indexer)
#
# KeyError: "['RatecodeID_six'] not in index"

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

model.fit(X_train_scaled, y_train)

print('Test accuracy', model.score(X_test_scaled, y_test))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-358-f4afdfb4cf12> in <module>
#       5 model.fit(X_train_scaled, y_train)
#       6
# ----> 7 print('Test accuracy', model.score(X_test_scaled, y_test))
#
# //anaconda3/lib/python3.7/site-packages/sklearn/base.py in score(self, X, y, sample_weight)
#     406         from .metrics import r2_score
#     407         from .metrics.regression import _check_reg_targets
# --> 408         y_pred = self.predict(X)
#     409         # XXX: Remove the check in 0.23
#     410         y_type, _, _, _ = _check_reg_targets(y, y_pred, None)
#
# //anaconda3/lib/python3.7/site-packages/sklearn/linear_model/base.py in predict(self, X)
#     219             Returns predicted values.
#     220         """
# --> 221         return self._decision_function(X)
#     222
#     223     _preprocess_data = staticmethod(_preprocess_data)
#
# //anaconda3/lib/python3.7/site-packages/sklearn/linear_model/base.py in _decision_function(self, X)
#     204         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     205         return safe_sparse_dot(X, self.coef_.T,
# --> 206                                dense_output=True) + self.intercept_
#     207
#     208     def predict(self, X):
#
# //anaconda3/lib/python3.7/site-packages/sklearn/utils/extmath.py in safe_sparse_dot(a, b, dense_output)
#     140         return ret
#     141     else:
# --> 142         return np.dot(a, b)
#     143
#     144
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# ValueError: shapes (2924,45) and (46,) not aligned: 45 (dim 1) != 46 (dim 0)

# %%
# remove negative values columns where it is not possible to have negative values
cols = ['fare_amount', 'extra', 'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge', 'total_amount']
for col in cols:
    X_train = X_train[X_train[col] >= 0]
    X_test = X_test[X_test[col] >= 0]
    
# remove zero values from where it is not possible to have zero values
cols = ['fare_amount', 'total_amount']
for col in cols:
    X_train = X_train[X_train[col] > 0]
    X_test = X_test[X_test[col] > 0]
    
X_train.describe()

# log transform numeric variables that do not contain zeros
for var in ['fare_amount', 'total_amount']:
    X_train[var] = np.log(X_train[var])
    X_test[var] = np.log(X_test[var])
